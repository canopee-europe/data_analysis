# %%
import pandas as pd
import json
import random
import numpy as np

# %% [markdown]
# # Filter values

# %%
# Input file
data = 'data.csv'

# Create lists
events = []
event_editions = []

# Read file
with open(data, "r", encoding="utf-8") as f:
    for line in f:
        try:
            data = json.loads(line.strip())  # Convertir en dictionnaire
            type_value = data.get("type")

            if type_value == "api::event.event":
                events.append(data)
            elif type_value == "api::event-edition.event-edition":
                event_editions.append(data)

        except json.JSONDecodeError:
            continue


# Convert lists to df
df_events = pd.DataFrame(events)
df_event_editions = pd.DataFrame(event_editions)

# %% [markdown]
# # Work on events

# %%
df_events = df_events.drop("type", axis=1)
df_events
# Out:
#    id                                               data
# 0  15  {'documentId': 'h4e8nx3mnj9fmd22983hg07x', 'de...
# 1  16  {'documentId': 'n8o21rucbzqrgv372m7ht13z', 'de...

# %%
df_events_filtered = df_events[["id"]].copy()

df_events_filtered["name"] = df_events["data"].apply(lambda x: x.get("name") if isinstance(x, dict) else None)
df_events_filtered["timezone"] = df_events["data"].apply(lambda x: x.get("timezone") if isinstance(x, dict) else None)

df_events_filtered
# Out:
#    id                      name             timezone
# 0  15  Marathon du lac d'Annecy         Europe/Paris
# 1  16                   Tabasco  Atlantic/Cape_verde

# %% [markdown]
# # Work on event editions

# %%
df_event_editions = df_event_editions.drop("type", axis=1)
df_event_editions
# Out:
#    id                                               data
# 0  23  {'documentId': 'escwtfkm1a1sd0di8mrzxgtk', 'ev...
# 1  24  {'documentId': 'r0d5fnp7939v19jemcu6edgs', 'ev...
# 2  25  {'documentId': 'mhfo3ftbcqx1l3uls8h50dym', 'ev...

# %%
df_event_editions_filtered = df_event_editions[["id"]].copy()

df_event_editions_filtered["name"] = df_event_editions["data"].apply(lambda x: x.get("name") if isinstance(x, dict) else None)
df_event_editions_filtered["date_start"] = df_event_editions["data"].apply(lambda x: x.get("date_start") if isinstance(x, dict) else None)
df_event_editions_filtered["date_end"] = df_event_editions["data"].apply(lambda x: x.get("date_end") if isinstance(x, dict) else None)
df_event_editions_filtered["annee"] = 2025

df_event_editions_filtered = df_event_editions_filtered.drop("id", axis=1)
df_event_editions_filtered.replace("Marathon du lac d'Annecy 2025", "Marathon du lac d'Annecy", inplace=True)
df_event_editions_filtered
# Out:
#                        name date_start date_end  annee
# 0  Marathon du lac d'Annecy       None     None   2025
# 1             Tabasco party       None     None   2025
# 2  Marathon du lac d'Annecy       None     None   2025

# %%
unique_value = df_event_editions_filtered.drop_duplicates()
unique_value.drop(columns=["date_start", "date_end"], axis=1, inplace=True)
unique_value["ville"] = ["Annecy", "T"]
unique_value
# Out:
# /tmp/ipykernel_26907/2683790391.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_value.drop(columns=["date_start", "date_end"], axis=1, inplace=True)
# /tmp/ipykernel_26907/2683790391.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_value["ville"] = ["Annecy", "T"]
#                        name  annee   ville
# 0  Marathon du lac d'Annecy   2025  Annecy
# 1             Tabasco party   2025       T

# %%
villes = ["Grenoble", "Montpellier", "Lyon", "Marseille", "Genève", "Paris", "Nantes", "Bordeaux"]

annees = list(range(2025, 2031))
evenements_par_annee = [5, 7, 8, 9, 10, 11]  # Nombre croissant d'événements


nouveaux_evenements = []
for annee, nombre in zip(annees, evenements_par_annee):
    for _ in range(nombre):
        ville = random.choice(villes)
        event_name = f"Marathon de {ville}"
        nouveaux_evenements.append({"name": event_name, "annee": annee, "ville": ville})

df_new_events = pd.DataFrame(nouveaux_evenements)
df_new_events
# Out:
#                        name  annee        ville
# 0      Marathon de Bordeaux   2025     Bordeaux
# 1        Marathon de Nantes   2025       Nantes
# 2      Marathon de Grenoble   2025     Grenoble
# 3        Marathon de Genève   2025       Genève
# 4      Marathon de Grenoble   2025     Grenoble
# 5   Marathon de Montpellier   2026  Montpellier
# 6      Marathon de Bordeaux   2026     Bordeaux
# 7        Marathon de Genève   2026       Genève
# 8         Marathon de Paris   2026        Paris
# 9          Marathon de Lyon   2026         Lyon
# 10       Marathon de Genève   2026       Genève
# 11         Marathon de Lyon   2026         Lyon
# 12     Marathon de Grenoble   2027     Grenoble
# 13       Marathon de Nantes   2027       Nantes
# 14         Marathon de Lyon   2027         Lyon
# 15       Marathon de Genève   2027       Genève
# 16    Marathon de Marseille   2027    Marseille
# 17        Marathon de Paris   2027        Paris
# 18     Marathon de Grenoble   2027     Grenoble
# 19         Marathon de Lyon   2027         Lyon
# 20       Marathon de Nantes   2028       Nantes
# 21     Marathon de Bordeaux   2028     Bordeaux
# 22  Marathon de Montpellier   2028  Montpellier
# 23         Marathon de Lyon   2028         Lyon
# 24        Marathon de Paris   2028        Paris
# 25       Marathon de Genève   2028       Genève
# 26  Marathon de Montpellier   2028  Montpellier
# 27    Marathon de Marseille   2028    Marseille
# 28  Marathon de Montpellier   2028  Montpellier
# 29       Marathon de Nantes   2029       Nantes
# 30        Marathon de Paris   2029        Paris
# 31       Marathon de Genève   2029       Genève
# 32         Marathon de Lyon   2029         Lyon
# 33         Marathon de Lyon   2029         Lyon
# 34    Marathon de Marseille   2029    Marseille
# 35         Marathon de Lyon   2029         Lyon
# 36  Marathon de Montpellier   2029  Montpellier
# 37  Marathon de Montpellier   2029  Montpellier
# 38     Marathon de Grenoble   2029     Grenoble
# 39       Marathon de Genève   2030       Genève
# 40    Marathon de Marseille   2030    Marseille
# 41        Marathon de Paris   2030        Paris
# 42  Marathon de Montpellier   2030  Montpellier
# 43       Marathon de Genève   2030       Genève
# 44    Marathon de Marseille   2030    Marseille
# 45     Marathon de Grenoble   2030     Grenoble
# 46     Marathon de Grenoble   2030     Grenoble
# 47         Marathon de Lyon   2030         Lyon
# 48       Marathon de Nantes   2030       Nantes
# 49       Marathon de Genève   2030       Genève

# %%
df_final = pd.concat([unique_value, df_new_events])
df_final
# Out:
#                         name  annee        ville
# 0   Marathon du lac d'Annecy   2025       Annecy
# 1              Tabasco party   2025            T
# 0       Marathon de Bordeaux   2025     Bordeaux
# 1         Marathon de Nantes   2025       Nantes
# 2       Marathon de Grenoble   2025     Grenoble
# 3         Marathon de Genève   2025       Genève
# 4       Marathon de Grenoble   2025     Grenoble
# 5    Marathon de Montpellier   2026  Montpellier
# 6       Marathon de Bordeaux   2026     Bordeaux
# 7         Marathon de Genève   2026       Genève
# 8          Marathon de Paris   2026        Paris
# 9           Marathon de Lyon   2026         Lyon
# 10        Marathon de Genève   2026       Genève
# 11          Marathon de Lyon   2026         Lyon
# 12      Marathon de Grenoble   2027     Grenoble
# 13        Marathon de Nantes   2027       Nantes
# 14          Marathon de Lyon   2027         Lyon
# 15        Marathon de Genève   2027       Genève
# 16     Marathon de Marseille   2027    Marseille
# 17         Marathon de Paris   2027        Paris
# 18      Marathon de Grenoble   2027     Grenoble
# 19          Marathon de Lyon   2027         Lyon
# 20        Marathon de Nantes   2028       Nantes
# 21      Marathon de Bordeaux   2028     Bordeaux
# 22   Marathon de Montpellier   2028  Montpellier
# 23          Marathon de Lyon   2028         Lyon
# 24         Marathon de Paris   2028        Paris
# 25        Marathon de Genève   2028       Genève
# 26   Marathon de Montpellier   2028  Montpellier
# 27     Marathon de Marseille   2028    Marseille
# 28   Marathon de Montpellier   2028  Montpellier
# 29        Marathon de Nantes   2029       Nantes
# 30         Marathon de Paris   2029        Paris
# 31        Marathon de Genève   2029       Genève
# 32          Marathon de Lyon   2029         Lyon
# 33          Marathon de Lyon   2029         Lyon
# 34     Marathon de Marseille   2029    Marseille
# 35          Marathon de Lyon   2029         Lyon
# 36   Marathon de Montpellier   2029  Montpellier
# 37   Marathon de Montpellier   2029  Montpellier
# 38      Marathon de Grenoble   2029     Grenoble
# 39        Marathon de Genève   2030       Genève
# 40     Marathon de Marseille   2030    Marseille
# 41         Marathon de Paris   2030        Paris
# 42   Marathon de Montpellier   2030  Montpellier
# 43        Marathon de Genève   2030       Genève
# 44     Marathon de Marseille   2030    Marseille
# 45      Marathon de Grenoble   2030     Grenoble
# 46      Marathon de Grenoble   2030     Grenoble
# 47          Marathon de Lyon   2030         Lyon
# 48        Marathon de Nantes   2030       Nantes
# 49        Marathon de Genève   2030       Genève

# %%
df_final.to_csv("events.csv", index=False)

# %%
df_for_looker = df_final.copy()

df_for_looker["Pays"] = "France"
df_for_looker
# Out:
#                         name  annee        ville    Pays
# 0   Marathon du lac d'Annecy   2025       Annecy  France
# 1              Tabasco party   2025            T  France
# 0       Marathon de Bordeaux   2025     Bordeaux  France
# 1         Marathon de Nantes   2025       Nantes  France
# 2       Marathon de Grenoble   2025     Grenoble  France
# 3         Marathon de Genève   2025       Genève  France
# 4       Marathon de Grenoble   2025     Grenoble  France
# 5    Marathon de Montpellier   2026  Montpellier  France
# 6       Marathon de Bordeaux   2026     Bordeaux  France
# 7         Marathon de Genève   2026       Genève  France
# 8          Marathon de Paris   2026        Paris  France
# 9           Marathon de Lyon   2026         Lyon  France
# 10        Marathon de Genève   2026       Genève  France
# 11          Marathon de Lyon   2026         Lyon  France
# 12      Marathon de Grenoble   2027     Grenoble  France
# 13        Marathon de Nantes   2027       Nantes  France
# 14          Marathon de Lyon   2027         Lyon  France
# 15        Marathon de Genève   2027       Genève  France
# 16     Marathon de Marseille   2027    Marseille  France
# 17         Marathon de Paris   2027        Paris  France
# 18      Marathon de Grenoble   2027     Grenoble  France
# 19          Marathon de Lyon   2027         Lyon  France
# 20        Marathon de Nantes   2028       Nantes  France
# 21      Marathon de Bordeaux   2028     Bordeaux  France
# 22   Marathon de Montpellier   2028  Montpellier  France
# 23          Marathon de Lyon   2028         Lyon  France
# 24         Marathon de Paris   2028        Paris  France
# 25        Marathon de Genève   2028       Genève  France
# 26   Marathon de Montpellier   2028  Montpellier  France
# 27     Marathon de Marseille   2028    Marseille  France
# 28   Marathon de Montpellier   2028  Montpellier  France
# 29        Marathon de Nantes   2029       Nantes  France
# 30         Marathon de Paris   2029        Paris  France
# 31        Marathon de Genève   2029       Genève  France
# 32          Marathon de Lyon   2029         Lyon  France
# 33          Marathon de Lyon   2029         Lyon  France
# 34     Marathon de Marseille   2029    Marseille  France
# 35          Marathon de Lyon   2029         Lyon  France
# 36   Marathon de Montpellier   2029  Montpellier  France
# 37   Marathon de Montpellier   2029  Montpellier  France
# 38      Marathon de Grenoble   2029     Grenoble  France
# 39        Marathon de Genève   2030       Genève  France
# 40     Marathon de Marseille   2030    Marseille  France
# 41         Marathon de Paris   2030        Paris  France
# 42   Marathon de Montpellier   2030  Montpellier  France
# 43        Marathon de Genève   2030       Genève  France
# 44     Marathon de Marseille   2030    Marseille  France
# 45      Marathon de Grenoble   2030     Grenoble  France
# 46      Marathon de Grenoble   2030     Grenoble  France
# 47          Marathon de Lyon   2030         Lyon  France
# 48        Marathon de Nantes   2030       Nantes  France
# 49        Marathon de Genève   2030       Genève  France

# %%
df_for_looker["population"] = np.random.randint(5000, 30001, size=len(df_for_looker))
df_for_looker
# Out:
#                         name  annee        ville    Pays  population
# 0   Marathon du lac d'Annecy   2025       Annecy  France        7825
# 1              Tabasco party   2025            T  France       19648
# 0       Marathon de Bordeaux   2025     Bordeaux  France       11004
# 1         Marathon de Nantes   2025       Nantes  France       14839
# 2       Marathon de Grenoble   2025     Grenoble  France       15672
# 3         Marathon de Genève   2025       Genève  France        7670
# 4       Marathon de Grenoble   2025     Grenoble  France       28136
# 5    Marathon de Montpellier   2026  Montpellier  France       20513
# 6       Marathon de Bordeaux   2026     Bordeaux  France       22448
# 7         Marathon de Genève   2026       Genève  France       10617
# 8          Marathon de Paris   2026        Paris  France       13951
# 9           Marathon de Lyon   2026         Lyon  France        6258
# 10        Marathon de Genève   2026       Genève  France       14241
# 11          Marathon de Lyon   2026         Lyon  France       25200
# 12      Marathon de Grenoble   2027     Grenoble  France        8370
# 13        Marathon de Nantes   2027       Nantes  France        9411
# 14          Marathon de Lyon   2027         Lyon  France        7244
# 15        Marathon de Genève   2027       Genève  France       13816
# 16     Marathon de Marseille   2027    Marseille  France       11619
# 17         Marathon de Paris   2027        Paris  France       18973
# 18      Marathon de Grenoble   2027     Grenoble  France        7497
# 19          Marathon de Lyon   2027         Lyon  France       23738
# 20        Marathon de Nantes   2028       Nantes  France       22207
# 21      Marathon de Bordeaux   2028     Bordeaux  France       27576
# 22   Marathon de Montpellier   2028  Montpellier  France       25997
# 23          Marathon de Lyon   2028         Lyon  France       14889
# 24         Marathon de Paris   2028        Paris  France       11270
# 25        Marathon de Genève   2028       Genève  France       15933
# 26   Marathon de Montpellier   2028  Montpellier  France        7180
# 27     Marathon de Marseille   2028    Marseille  France       12381
# 28   Marathon de Montpellier   2028  Montpellier  France       27723
# 29        Marathon de Nantes   2029       Nantes  France       23899
# 30         Marathon de Paris   2029        Paris  France        6852
# 31        Marathon de Genève   2029       Genève  France        5561
# 32          Marathon de Lyon   2029         Lyon  France       20306
# 33          Marathon de Lyon   2029         Lyon  France       14767
# 34     Marathon de Marseille   2029    Marseille  France        8430
# 35          Marathon de Lyon   2029         Lyon  France       16003
# 36   Marathon de Montpellier   2029  Montpellier  France        5326
# 37   Marathon de Montpellier   2029  Montpellier  France       22500
# 38      Marathon de Grenoble   2029     Grenoble  France       26732
# 39        Marathon de Genève   2030       Genève  France       11744
# 40     Marathon de Marseille   2030    Marseille  France       25169
# 41         Marathon de Paris   2030        Paris  France       13997
# 42   Marathon de Montpellier   2030  Montpellier  France       22723
# 43        Marathon de Genève   2030       Genève  France       29023
# 44     Marathon de Marseille   2030    Marseille  France       26002
# 45      Marathon de Grenoble   2030     Grenoble  France        5720
# 46      Marathon de Grenoble   2030     Grenoble  France       19157
# 47          Marathon de Lyon   2030         Lyon  France       15823
# 48        Marathon de Nantes   2030       Nantes  France        8297
# 49        Marathon de Genève   2030       Genève  France       16703

# %%
df_for_looker.to_csv("events2.csv", index=False)
